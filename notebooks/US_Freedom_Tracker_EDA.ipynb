# %%
# %load ~/jupyter_imports.py
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# make plots look nice
plt.rcParams['font.size'] = 14
plt.rcParams['axes.labelsize'] = 'large'
plt.rcParams['xtick.labelsize'] = 'large'
plt.rcParams['ytick.labelsize'] = 'large'
plt.rcParams['lines.linewidth'] = 3

# %%
FT = pd.read_csv('../data/incidents.csv')
FT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 449 entries, 0 to 448
# Data columns (total 62 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   title                                        449 non-null    object
#  1   slug                                         449 non-null    object
#  2   first_published_at                           449 non-null    object
#  3   last_published_at                            449 non-null    object
#  4   latest_revision_created_at                   449 non-null    object
#  5   authors                                      0 non-null      float64
#  6   updates                                      91 non-null     object
#  7   categories                                   448 non-null    object
#  8   links                                        207 non-null    object
#  9   equipment_seized                             33 non-null     object
#  10  equipment_broken                             23 non-null     object
#  11  targeted_journalists                         330 non-null    object
#  12  date                                         449 non-null    object
#  13  exact_date_unknown                           449 non-null    bool
#  14  affiliation                                  449 non-null    object
#  15  city                                         449 non-null    object
#  16  state                                        449 non-null    object
#  17  body                                         449 non-null    object
#  18  teaser                                       52 non-null     object
#  19  teaser_image                                 449 non-null    object
#  20  primary_video                                449 non-null    object
#  21  image_caption                                329 non-null    object
#  22  arrest_status                                449 non-null    object
#  23  status_of_charges                            449 non-null    object
#  24  release_date                                 449 non-null    object
#  25  detention_date                               449 non-null    object
#  26  unnecessary_use_of_force                     449 non-null    bool
#  27  lawsuit_name                                 449 non-null    object
#  28  status_of_seized_equipment                   449 non-null    object
#  29  is_search_warrant_obtained                   449 non-null    bool
#  30  actor                                        449 non-null    object
#  31  border_point                                 449 non-null    object
#  32  stopped_at_border                            449 non-null    bool
#  33  target_us_citizenship_status                 449 non-null    object
#  34  denial_of_entry                              449 non-null    bool
#  35  stopped_previously                           449 non-null    bool
#  36  did_authorities_ask_for_device_access        449 non-null    object
#  37  did_authorities_ask_for_social_media_user    449 non-null    object
#  38  did_authorities_ask_for_social_media_pass    449 non-null    object
#  39  did_authorities_ask_about_work               449 non-null    object
#  40  were_devices_searched_or_seized              449 non-null    object
#  41  assailant                                    449 non-null    object
#  42  was_journalist_targeted                      449 non-null    object
#  43  charged_under_espionage_act                  449 non-null    bool
#  44  subpoena_type                                449 non-null    object
#  45  subpoena_statuses                            449 non-null    object
#  46  held_in_contempt                             449 non-null    object
#  47  detention_status                             449 non-null    object
#  48  third_party_in_possession_of_communications  449 non-null    object
#  49  third_party_business                         449 non-null    object
#  50  legal_order_type                             449 non-null    object
#  51  status_of_prior_restraint                    449 non-null    object
#  52  targets                                      398 non-null    object
#  53  targeted_institutions                        84 non-null     object
#  54  tags                                         211 non-null    object
#  55  current_charges                              22 non-null     object
#  56  dropped_charges                              29 non-null     object
#  57  venue                                        4 non-null      object
#  58  target_nationality                           12 non-null     object
#  59  workers_whose_communications_were_obtained   5 non-null      object
#  60  targets_whose_communications_were_obtained   5 non-null      object
#  61  politicians_or_public_figures_involved       38 non-null     object
# dtypes: bool(7), float64(1), object(54)
# memory usage: 196.1+ KB

# %%
FT.head()
# Out:
#                                                title  \
# 0  Five members of neo-Nazi group arrested for al...
# 1  Fresno Bee reporters barred from event with ca...
# 2  State Department Classifies Five Chinese State...
# 3  FBI arrests man following threatening calls to...
# 4  NYPD arrests photojournalist, charges him with...
#
#                                                 slug  \
# 0  https://pressfreedomtracker.us/all-incidents/f...
# 1  https://pressfreedomtracker.us/all-incidents/f...
# 2  https://pressfreedomtracker.us/all-incidents/s...
# 3  https://pressfreedomtracker.us/all-incidents/f...
# 4  https://pressfreedomtracker.us/all-incidents/n...
#
#                  first_published_at                 last_published_at  \
# 0  2020-03-10 18:56:58.597549+00:00  2020-03-10 18:56:58.597549+00:00
# 1  2020-02-27 16:50:35.363402+00:00  2020-02-27 16:50:35.363402+00:00
# 2  2020-02-28 20:20:00.400052+00:00  2020-03-17 18:21:36.001122+00:00
# 3  2020-03-10 18:33:49.887425+00:00  2020-03-10 18:33:49.887425+00:00
# 4  2020-02-14 21:28:47.367239+00:00  2020-02-14 21:28:47.367239+00:00
#
#          latest_revision_created_at  authors  \
# 0  2020-03-10 18:56:58.525989+00:00      NaN
# 1  2020-02-27 16:50:35.293448+00:00      NaN
# 2  2020-03-17 18:21:35.937076+00:00      NaN
# 3  2020-03-10 18:33:49.810405+00:00      NaN
# 4  2020-02-14 21:28:47.314870+00:00      NaN
#
#                                              updates  \
# 0                                                NaN
# 1                                                NaN
# 2  (2020-03-02 10:57:00+00:00) Four of the five C...
# 3                                                NaN
# 4                                                NaN
#
#                  categories links equipment_seized  ...    targets  \
# 0            Other Incident   NaN              NaN  ...        NaN
# 1          Denial of Access   NaN              NaN  ...        NaN
# 2            Other Incident   NaN              NaN  ...        NaN
# 3            Other Incident   NaN              NaN  ...        NaN
# 4  Arrest / Criminal Charge   NaN              NaN  ...  Amr Afiky
#
#                                targeted_institutions tags     current_charges  \
# 0                                                NaN  NaN                 NaN
# 1                                     The Fresno Bee  NaN                 NaN
# 2  Xinhua News Agency, China Global Television Ne...  NaN                 NaN
# 3                                                NaN  NaN                 NaN
# 4                                                NaN  NaN  disorderly conduct
#
#   dropped_charges venue target_nationality  \
# 0             NaN   NaN                NaN
# 1             NaN   NaN                NaN
# 2             NaN   NaN                NaN
# 3             NaN   NaN                NaN
# 4             NaN   NaN                NaN
#
#   workers_whose_communications_were_obtained  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   targets_whose_communications_were_obtained  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   politicians_or_public_figures_involved
# 0                                    NaN
# 1                            Devin Nunes
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
# [5 rows x 62 columns]

# %%
FT['authors'].value_counts()
# Out:
# Series([], Name: authors, dtype: int64)

# %%
FT.drop('authors',axis=1,inplace=True)

# %%
FT['state'].value_counts()

# %%
FT['city'].value_counts()

# %%
FT['categories'].value_counts()
